# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder


date_cols = ['Stime', 'Ltime']
fields1 = ['ct_flw_http_mthd', 'is_ftp_login', 'ct_ftp_cmd', 'Stime', 'Ltime']
fields2 = ['is_ftp_login', 'ct_ftp_cmd', 'Stime', 'Ltime']
fields3 = ['ct_ftp_cmd', 'Stime', 'Ltime']
cols = [
    'srcip',
    'sport',
    'dstip',
    'dsport',
    'proto',
    'state',
    'dur',
    'sbytes',
    'dbytes',
    'sttl',
    'dttl',
    'sloss',
    'dloss',
    'service',
    'Sload',
    'Dload',
    'Spkts',
    'Dpkts',
    'swin',
    'dwin',
    'stcpb',
    'dtcpb',
    'smeansz',
    'dmeansz',
    
    'trans_depth',
    'res_bdy_len',
    'Sjit',
    'Djit',
    'Stime',
    'Ltime',
    'Sintpkt',
    'Dintpkt',
    'tcprtt',
    'synack',
    'ackdat',
    'is_sm_ips_ports',
    'ct_state_ttl',
    
#     'ct_flw_http_mthd',
#     'is_ftp_login',
#     'ct_ftp_cmd',
    
    'ct_srv_src',
    'ct_srv_dst',
    
#     'ct_dst_ltm',
#     'ct_src_ltm',
    
    'ct_src_dport_ltm',
    'ct_dst_sport_ltm',
    'ct_dst_src_ltm',
    'attack_cat',
    'Label',
]
fields5 = ['attack_cat', 'Stime', 'Ltime']


def strip_int(text):
    return int(text.strip(' '))

def ip_to_int(ip):
    z = ''
    parts = ip.split('.')
    for prt in range(3):
        if len(parts[prt]) == 3:
            z = parts[prt] + z
        elif len(parts[prt]) == 2:
            z = '0' + parts[prt] + z
        else:
            z = '00' + parts[prt] + z
    return int(z)

def encode_attack_cat(cat):
    mapping = {
        'Generic': 1,
        'Fuzzers': 2,
        'Exploits': 3,
        'DoS': 4,
        'Reconnaissance': 5,
        'Backdoor': 6,
        'Backdoors': 6,
        'Analysis': 7,
        'Shellcode': 8,
        'Worms': 9,
    }
    if (not cat):
        return 0
    return mapping[cat.strip(' ')]

def decode_attack_cat(encoded_cat):
    mapping = {
        0: '',
        1: 'Generic',
        2: 'Fuzzers',
        3: 'Exploits',
        4: 'DoS',
        5: 'Reconnaissance',
        6: 'Backdoors',
        7: 'Analysis',
        8: 'Shellcode',
        9: 'Worms',
    }
    return mapping[encoded_cat]

def encode_state(state):
    mapping = {
        'CON': 0,
        'FIN': 1,
        'INT': 2,
        'REQ': 3,
        'URH': 4,
        'RST': 5,
        'ECR': 6,
        'ECO': 7,
        'CLO': 8,
        'PAR': 9,
        'ACC': 10,
        'URN': 11,
        'MAS': 12,
    }
    return mapping[state]

def sanitize_port(port):
    return int(port.replace('-', 0))

converters = {
    'srcip': ip_to_int,
    'dstip': ip_to_int,
}

# Read csv
df = pd.read_csv(
    '../data/UNSW-NB15-BALANCED-TRAIN.csv',
    parse_dates=date_cols,
    usecols=cols,
    skipinitialspace=True,
    converters=converters
)

df['sport'] = df['sport'].replace('-', 0)
df['dsport'] = df['dsport'].replace('-', 0)
df['sport'] = df['sport'].apply(lambda x: int(str(x), 16))
df['dsport'] = df['dsport'].apply(lambda x: int(str(x), 16))
df['service'] = df['service'].replace('-', '')


le = LabelEncoder()
df['proto'] = le.fit_transform(df['proto'])
df['state'] = le.fit_transform(df['state'])
df['service'] = le.fit_transform(df['service'])
df['attack_cat'] = le.fit_transform(df['attack_cat'])

df.head()
# Out:
# /var/folders/r1/72xs0cc52vsfvf5nkpbx2fhh0000gn/T/ipykernel_63311/2613928297.py:146: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(
#        srcip   sport      dstip  dsport  proto  state       dur  sbytes  \
# 0     166059  349328  126171149      83    119      2  0.001050     146
# 1     166059  157526  126171149      33    113      5  4.264797    2934
# 2  176045175    4163  126171149      83    119      6  0.000003     114
# 3  176045175    4163  126171149      83    119      6  0.000003     114
# 4     166059  214130  126171149   66601    113      5  0.052957    3718
#
#    dbytes  sttl  ...    ackdat  is_sm_ips_ports  ct_state_ttl  ct_srv_src  \
# 0     178    31  ...  0.000000                0             0           3
# 1    3738    31  ...  0.000134                0             0           5
# 2       0   254  ...  0.000000                0             2          17
# 3       0   254  ...  0.000000                0             2          25
# 4   43086    31  ...  0.000130                0             0           5
#
#    ct_srv_dst  ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm  attack_cat  \
# 0           4                 1                 1               1          13
# 1           5                 5                 5               8          13
# 2          17                14                14              17           7
# 3          25                25                25              25           7
# 4           8                 1                 1               2          13
#
#    Label
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#
# [5 rows x 44 columns]

# %%
df.describe()
# Out:
#               srcip          sport         dstip        dsport          proto  \
# count  4.497960e+05  449796.000000  4.497960e+05  4.497960e+05  449796.000000
# mean   9.646951e+07  166478.437687  1.284399e+08  4.295583e+04     114.453261
# std    8.570929e+07  139797.213314  1.231686e+07  1.140547e+06      12.583730
# min    1.660590e+05       0.000000  2.240000e+02  0.000000e+00       0.000000
# 25%    1.660590e+05    4163.000000  1.261711e+08  8.300000e+01     113.000000
# 50%    1.760452e+08  161571.000000  1.261711e+08  8.300000e+01     119.000000
# 75%    1.760452e+08  291897.000000  1.261711e+08  5.923000e+03     119.000000
# max    2.411682e+08  415029.000000  2.411682e+08  5.389893e+08     132.000000
#
#                state            dur        sbytes        dbytes  \
# count  449796.000000  449796.000000  4.497960e+05  4.497960e+05
# mean        5.085528       0.694259  5.092681e+03  2.277625e+04
# std         1.293619      13.697272  1.157077e+05  1.449404e+05
# min         0.000000       0.000000  0.000000e+00  0.000000e+00
# 25%         5.000000       0.000008  1.140000e+02  0.000000e+00
# 50%         5.000000       0.001058  2.640000e+02  1.780000e+02
# 75%         6.000000       0.098976  2.054000e+03  3.276000e+03
# max        12.000000    8760.777344  1.435577e+07  1.465753e+07
#
#                 sttl  ...         ackdat  is_sm_ips_ports   ct_state_ttl  \
# count  449796.000000  ...  449796.000000    449796.000000  449796.000000
# mean      138.566168  ...       0.006775         0.000972       0.931353
# std       109.317462  ...       0.026773         0.031155       0.982520
# min         0.000000  ...       0.000000         0.000000       0.000000
# 25%        31.000000  ...       0.000000         0.000000       0.000000
# 50%        62.000000  ...       0.000000         0.000000       1.000000
# 75%       254.000000  ...       0.000136         0.000000       2.000000
# max       255.000000  ...       3.551121         1.000000       6.000000
#
#           ct_srv_src     ct_srv_dst  ct_src_dport_ltm  ct_dst_sport_ltm  \
# count  449796.000000  449796.000000     449796.000000     449796.000000
# mean       13.858387      13.683721          8.416918          6.496405
# std        13.818018      13.880075         11.033970          7.860205
# min         1.000000       1.000000          1.000000          1.000000
# 25%         3.000000       3.000000          1.000000          1.000000
# 50%         7.000000       7.000000          2.000000          1.000000
# 75%        24.000000      24.000000         16.000000         13.000000
# max        67.000000      67.000000         67.000000         60.000000
#
#        ct_dst_src_ltm     attack_cat          Label
# count   449796.000000  449796.000000  449796.000000
# mean        12.401215       9.646331       0.500000
# std         14.575122       3.540252       0.500001
# min          1.000000       0.000000       0.000000
# 25%          1.000000       7.000000       0.000000
# 50%          4.000000      12.500000       0.500000
# 75%         24.000000      13.000000       1.000000
# max         67.000000      13.000000       1.000000
#
# [8 rows x 42 columns]

# %%
df.values
# Out:
# array([[166059, 349328, 126171149, ..., 1, 13, 0],
#        [166059, 157526, 126171149, ..., 8, 13, 0],
#        [176045175, 4163, 126171149, ..., 17, 7, 1],
#        ...,
#        [166059, 201106, 126171149, ..., 1, 13, 0],
#        [176045175, 4163, 126171149, ..., 41, 7, 1],
#        [166059, 354344, 126171149, ..., 1, 13, 0]], dtype=object)

# %%
X = df.drop(columns=['attack_cat', 'Label'])
y = df['Label']

X
# Out:
#             srcip   sport      dstip  dsport  proto  state       dur  sbytes  \
# 0          166059  349328  126171149      83    119      2  0.001050     146
# 1          166059  157526  126171149      33    113      5  4.264797    2934
# 2       176045175    4163  126171149      83    119      6  0.000003     114
# 3       176045175    4163  126171149      83    119      6  0.000003     114
# 4          166059  214130  126171149   66601    113      5  0.052957    3718
# ...           ...     ...        ...     ...    ...    ...       ...     ...
# 449791  176045175   75571  126171149      33    113      5  0.977167    1072
# 449792  176045175    4163  126171149      83    119      6  0.000004     114
# 449793     166059  201106  126171149  161686    113      5  0.019671    3182
# 449794  176045175    4163  126171149      83    119      6  0.000010     114
# 449795     166059  354344  126171149  348485    113      5  0.027818    2854
#
#         dbytes  sttl  ...    tcprtt    synack    ackdat  is_sm_ips_ports  \
# 0          178    31  ...  0.000000  0.000000  0.000000                0
# 1         3738    31  ...  0.001011  0.000877  0.000134                0
# 2            0   254  ...  0.000000  0.000000  0.000000                0
# 3            0   254  ...  0.000000  0.000000  0.000000                0
# 4        43086    31  ...  0.000650  0.000520  0.000130                0
# ...        ...   ...  ...       ...       ...       ...              ...
# 449791    1656    62  ...  0.051045  0.006791  0.044254                0
# 449792       0   254  ...  0.000000  0.000000  0.000000                0
# 449793   35916    31  ...  0.000765  0.000609  0.000156                0
# 449794       0   254  ...  0.000000  0.000000  0.000000                0
# 449795   31402    31  ...  0.000680  0.000533  0.000147                0
#
#         ct_state_ttl  ct_srv_src  ct_srv_dst  ct_src_dport_ltm  \
# 0                  0           3           4                 1
# 1                  0           5           5                 5
# 2                  2          17          17                14
# 3                  2          25          25                25
# 4                  0           5           8                 1
# ...              ...         ...         ...               ...
# 449791             1           1           1                 1
# 449792             2          16          16                 7
# 449793             0           2           8                 1
# 449794             2          41          41                25
# 449795             0          16           8                 1
#
#         ct_dst_sport_ltm  ct_dst_src_ltm
# 0                      1               1
# 1                      5               8
# 2                     14              17
# 3                     25              25
# 4                      1               2
# ...                  ...             ...
# 449791                 1               2
# 449792                 3               7
# 449793                 1               1
# 449794                14              41
# 449795                 1               1
#
# [449796 rows x 42 columns]

# %%
# X_train_validation includes training set and validation set
# X_test includes test set
# y_train_validation includes the labels for both the training set and validation set
# y_test includes the labels for the test set
X_train_validation, X_test, y_train_validation, y_test = train_test_split(X, y, test_size=0.2)

X_train_validation.head()
# Out:
#             srcip   sport      dstip  dsport  proto  state       dur  sbytes  \
# 354382  176045175  336256  126171149     128    113      5  0.289019     846
# 350354     166059   17446  126171149      83    119      2  0.001043     146
# 387583     166059  198713  126171149     128    113      5  1.277831    1684
# 28925      166059   96114  126171149   82073    113      5  0.009857    2334
# 329623  176045175       0  126171149       0     84      6  0.000009     200
#
#         dbytes  sttl  ...    tcprtt    synack    ackdat  is_sm_ips_ports  \
# 354382    1340    62  ...  0.056965  0.010531  0.046434                0
# 350354     178    31  ...  0.000000  0.000000  0.000000                0
# 387583   10168    31  ...  0.000726  0.000562  0.000164                0
# 28925    16528    31  ...  0.000759  0.000618  0.000141                0
# 329623       0   254  ...  0.000000  0.000000  0.000000                0
#
#         ct_state_ttl  ct_srv_src  ct_srv_dst  ct_src_dport_ltm  \
# 354382             1           1           1                 1
# 350354             0          22          11                 1
# 387583             0           1           3                 1
# 28925              0           2          14                 1
# 329623             2           5           5                 3
#
#         ct_dst_sport_ltm  ct_dst_src_ltm
# 354382                 1               1
# 350354                 1               1
# 387583                 1               2
# 28925                  1               1
# 329623                 3               5
#
# [5 rows x 42 columns]

# %%
# X_train is the training set
# X_validation is the validation set
# y_train is the labels for the training set
# y_validation is the labels for the validation set
X_train, X_validation, y_train, y_validation = train_test_split(X_train_validation, y_train_validation, test_size=0.2)

X_train.head()
# Out:
#             srcip   sport      dstip  dsport  proto  state       dur  sbytes  \
# 364547     166059  407428  126171149      34    113      5  0.020219    9400
# 221876     166059  345139  126171149   26753    113      5  0.013464    1540
# 216009  176045175    4163  126171149      83    119      6  0.000004     114
# 237501     166059   90627  126171149     128    113      5  1.160631    1684
# 158340     166059  149350  126171149  366600    113      5  0.017945    2750
#
#         dbytes  sttl  ...    tcprtt    synack    ackdat  is_sm_ips_ports  \
# 364547   12298    31  ...  0.000690  0.000568  0.000122                0
# 221876    1644    31  ...  0.000569  0.000453  0.000116                0
# 216009       0   254  ...  0.000000  0.000000  0.000000                0
# 237501   10168    31  ...  0.000662  0.000539  0.000123                0
# 158340   26406    31  ...  0.000732  0.000599  0.000133                0
#
#         ct_state_ttl  ct_srv_src  ct_srv_dst  ct_src_dport_ltm  \
# 364547             0           3           1                 1
# 221876             0           5           6                 3
# 216009             2          30          30                30
# 237501             0           3           1                 1
# 158340             0          10           4                 1
#
#         ct_dst_sport_ltm  ct_dst_src_ltm
# 364547                 1               1
# 221876                 1               5
# 216009                12              30
# 237501                 1               1
# 158340                 1               1
#
# [5 rows x 42 columns]

# %%
# Train
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#
# Dpkts               0.140156    0.140841          0.144891          0.156632
# swin                0.546790    0.555351          0.533406          0.573061
# dwin                0.546750    0.555210          0.532533          0.572165
# stcpb               0.437437    0.444176          0.425598          0.457330
# dtcpb               0.436851    0.443569          0.425603          0.457203
# smeansz             0.214131    0.213089          0.183379          0.196548
# dmeansz             0.355438    0.364344          0.370540          0.395376
# trans_depth         0.154180    0.152577          0.116872          0.123969
# res_bdy_len         0.050973    0.049850          0.037889          0.040047
# Sjit                0.055262    0.057311          0.047790          0.049880
# Djit                0.143603    0.142136          0.118825          0.125684
# Sintpkt             0.051552    0.050509          0.037945          0.037483
# Dintpkt             0.043703    0.044081          0.033297          0.034028
# tcprtt              0.200361    0.206391          0.164803          0.174627
# synack              0.178607    0.184223          0.148169          0.157246
# ackdat              0.200972    0.206750          0.163892          0.173386
# is_sm_ips_ports     0.027109    0.026535          0.018747          0.018735
# ct_state_ttl        0.525395    0.527635          0.514188          0.553631
# ct_srv_src          1.000000    0.983491          0.878827          0.848359
# ct_srv_dst          0.983491    1.000000          0.881697          0.852668
# ct_src_dport_ltm    0.878827    0.881697          1.000000          0.906881
# ct_dst_sport_ltm    0.848359    0.852668          0.906881          1.000000
# ct_dst_src_ltm      0.972947    0.977093          0.894806          0.872841
#
#                   ct_dst_src_ltm
# srcip                   0.595763
# sport                   0.164443
# dstip                   0.243760
# dsport                  0.021173
# proto                   0.219977
# state                   0.498520
# dur                     0.106387
# sbytes                  0.031371
# dbytes                  0.102504
# sttl                    0.576710
# dttl                    0.366519
# sloss                   0.067954
# dloss                   0.130758
# service                 0.035693
# Sload                   0.306527
# Dload                   0.296705
# Spkts                   0.147478
# Dpkts                   0.163376
# swin                    0.585191
# dwin                    0.585271
# stcpb                   0.467808
# dtcpb                   0.467653
# smeansz                 0.192033
# dmeansz                 0.413358
# trans_depth             0.133785
# res_bdy_len             0.041397
# Sjit                    0.052429
# Djit                    0.135481
# Sintpkt                 0.044062
# Dintpkt                 0.038438
# tcprtt                  0.178066
# synack                  0.159546
# ackdat                  0.177696
# is_sm_ips_ports         0.022603
# ct_state_ttl            0.577538
# ct_srv_src              0.972947
# ct_srv_dst              0.977093
# ct_src_dport_ltm        0.894806
# ct_dst_sport_ltm        0.872841
# ct_dst_src_ltm          1.000000
#
# [40 rows x 40 columns]

# %%
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
upper.head()
# Out:
#         srcip     sport     dstip    dsport     proto     state       dur  \
# srcip     NaN  0.222034  0.069884  0.026011  0.016012  0.629746  0.027422
# sport     NaN       NaN  0.020551  0.005123  0.142196  0.186677  0.039229
# dstip     NaN       NaN       NaN  0.006534  0.075958  0.116439  0.091786
# dsport    NaN       NaN       NaN       NaN  0.020170  0.006027  0.003660
# proto     NaN       NaN       NaN       NaN       NaN  0.073926  0.210411
#
#           sbytes    dbytes      sttl  ...    tcprtt    synack    ackdat  \
# srcip   0.004483  0.143386  0.906766  ...  0.226278  0.199044  0.229962
# sport   0.008771  0.037608  0.221860  ...  0.091341  0.083550  0.089232
# dstip   0.009526  0.028709  0.124582  ...  0.046315  0.041724  0.045963
# dsport  0.000549  0.000934  0.023362  ...  0.004117  0.003585  0.004225
# proto   0.006479  0.017822  0.016613  ...  0.029046  0.026169  0.028823
#
#         is_sm_ips_ports  ct_state_ttl  ct_srv_src  ct_srv_dst  \
# srcip          0.028536      0.880653    0.531331    0.532702
# sport          0.036666      0.238567    0.147156    0.149670
# dstip          0.118612      0.165665    0.239410    0.239318
# dsport         0.000958      0.021802    0.015872    0.016526
# proto          0.265169      0.021316    0.231091    0.231724
#
#         ct_src_dport_ltm  ct_dst_sport_ltm  ct_dst_src_ltm
# srcip           0.538267          0.581248        0.595763
# sport           0.163015          0.205147        0.164443
# dstip           0.236287          0.250846        0.243760
# dsport          0.020258          0.021071        0.021173
# proto           0.212455          0.216525        0.219977
#
# [5 rows x 40 columns]

# %%
to_drop = []

for column in upper.columns:
    print('==========', column)
#     print(upper[column])
    for index, correlation in enumerate(upper[column]):
#         print(upper[column][index])
        if (correlation > threshold):
            print(upper.columns[index])
            to_drop.push(upper.columns[index])
            
to_drop
# Out:
# ========== srcip
# srcip              NaN
# sport              NaN
# dstip              NaN
# dsport             NaN
# proto              NaN
# state              NaN
# dur                NaN
# sbytes             NaN
# dbytes             NaN
# sttl               NaN
# dttl               NaN
# sloss              NaN
# dloss              NaN
# service            NaN
# Sload              NaN
# Dload              NaN
# Spkts              NaN
# Dpkts              NaN
# swin               NaN
# dwin               NaN
# stcpb              NaN
# dtcpb              NaN
# smeansz            NaN
# dmeansz            NaN
# trans_depth        NaN
# res_bdy_len        NaN
# Sjit               NaN
# Djit               NaN
# Sintpkt            NaN
# Dintpkt            NaN
# tcprtt             NaN
# synack             NaN
# ackdat             NaN
# is_sm_ips_ports    NaN
# ct_state_ttl       NaN
# ct_srv_src         NaN
# ct_srv_dst         NaN
# ct_src_dport_ltm   NaN
# ct_dst_sport_ltm   NaN
# ct_dst_src_ltm     NaN
# Name: srcip, dtype: float64
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== sport
# srcip               0.222034
# sport                    NaN
# dstip                    NaN
# dsport                   NaN
# proto                    NaN
# state                    NaN
# dur                      NaN
# sbytes                   NaN
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: sport, dtype: float64
# 0.2220336021673089
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== dstip
# srcip               0.069884
# sport               0.020551
# dstip                    NaN
# dsport                   NaN
# proto                    NaN
# state                    NaN
# dur                      NaN
# sbytes                   NaN
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: dstip, dtype: float64
# 0.06988364380468098
# 0.020551224092380735
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== dsport
# srcip               0.026011
# sport               0.005123
# dstip               0.006534
# dsport                   NaN
# proto                    NaN
# state                    NaN
# dur                      NaN
# sbytes                   NaN
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: dsport, dtype: float64
# 0.026010613209385195
# 0.005123222542081302
# 0.006533536013533355
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== proto
# srcip               0.016012
# sport               0.142196
# dstip               0.075958
# dsport              0.020170
# proto                    NaN
# state                    NaN
# dur                      NaN
# sbytes                   NaN
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: proto, dtype: float64
# 0.016012293855887257
# 0.14219638864017836
# 0.07595786872081783
# 0.020170149420761174
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== state
# srcip               0.629746
# sport               0.186677
# dstip               0.116439
# dsport              0.006027
# proto               0.073926
# state                    NaN
# dur                      NaN
# sbytes                   NaN
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: state, dtype: float64
# 0.6297455128460975
# 0.18667656979682448
# 0.11643913109063413
# 0.006026805098300627
# 0.07392590254128117
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== dur
# srcip               0.027422
# sport               0.039229
# dstip               0.091786
# dsport              0.003660
# proto               0.210411
# state               0.049233
# dur                      NaN
# sbytes                   NaN
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: dur, dtype: float64
# 0.027422157763752127
# 0.039229383485117425
# 0.09178614619938837
# 0.0036603706352226102
# 0.21041110231924792
# 0.049232751544316944
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== sbytes
# srcip               0.004483
# sport               0.008771
# dstip               0.009526
# dsport              0.000549
# proto               0.006479
# state               0.021237
# dur                 0.194652
# sbytes                   NaN
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: sbytes, dtype: float64
# 0.004483007100223491
# 0.008770834787421869
# 0.009526330808450783
# 0.0005494574663937786
# 0.006478734212882092
# 0.021237070779332807
# 0.194651817895255
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== dbytes
# srcip               0.143386
# sport               0.037608
# dstip               0.028709
# dsport              0.000934
# proto               0.017822
# state               0.021296
# dur                 0.252027
# sbytes              0.019065
# dbytes                   NaN
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: dbytes, dtype: float64
# 0.1433859671613502
# 0.03760841246132007
# 0.02870941109725438
# 0.0009336540408779464
# 0.01782223491374855
# 0.021295678088799765
# 0.25202667688101793
# 0.019065389279179848
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== sttl
# srcip               0.906766
# sport               0.221860
# dstip               0.124582
# dsport              0.023362
# proto               0.016613
# state               0.590616
# dur                 0.014109
# sbytes              0.013857
# dbytes              0.147804
# sttl                     NaN
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: sttl, dtype: float64
# 0.9067663311545382
# 0.22186006755926788
# 0.124581536930794
# 0.0233623623079288
# 0.016613056331209027
# 0.5906163197820616
# 0.014109167406616302
# 0.013856751536205058
# 0.1478038427713746
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== dttl
# srcip               0.119844
# sport               0.155675
# dstip               0.097482
# dsport              0.000845
# proto               0.036422
# state               0.165367
# dur                 0.099186
# sbytes              0.071297
# dbytes              0.030839
# sttl                0.039134
# dttl                     NaN
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: dttl, dtype: float64
# 0.11984405819614939
# 0.15567528401784586
# 0.09748245242445465
# 0.00084459428011841
# 0.0364223110912877
# 0.1653673648684395
# 0.0991859483683192
# 0.07129654454418435
# 0.030839471197503684
# 0.0391339060438869
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# ========== sloss
# srcip               0.043730
# sport               0.023708
# dstip               0.019677
# dsport              0.000691
# proto               0.010946
# state               0.025114
# dur                 0.204398
# sbytes              0.989945
# dbytes              0.046376
# sttl                0.059697
# dttl                0.084747
# sloss                    NaN
# dloss                    NaN
# service                  NaN
# Sload                    NaN
# Dload                    NaN
# Spkts                    NaN
# Dpkts                    NaN
# swin                     NaN
# dwin                     NaN
# stcpb                    NaN
# dtcpb                    NaN
# smeansz                  NaN
# dmeansz                  NaN
# trans_depth              NaN
# res_bdy_len              NaN
# Sjit                     NaN
# Djit                     NaN
# Sintpkt                  NaN
# Dintpkt                  NaN
# tcprtt                   NaN
# synack                   NaN
# ackdat                   NaN
# is_sm_ips_ports          NaN
# ct_state_ttl             NaN
# ct_srv_src               NaN
# ct_srv_dst               NaN
# ct_src_dport_ltm         NaN
# ct_dst_sport_ltm         NaN
# ct_dst_src_ltm           NaN
# Name: sloss, dtype: float64
# 0.043729695093934075
# 0.02370849669510073
# 0.019676610781936398
# 0.0006908006289122799
# 0.010946006486459459
# 0.02511394577495686
# 0.2043977509885725
# 0.9899451395381776
# sbytes
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[206], line 10
#       8         if (correlation > threshold):
#       9             print(upper.columns[index])
# ---> 10             to_drop.push(upper.columns[index])
#      12 to_drop
#
# AttributeError: 'list' object has no attribute 'push'
